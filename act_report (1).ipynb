# %% [markdown]
# ![WhatsApp%20Image%202022-07-01%20at%208.27.31%20AM.jpeg](attachment:WhatsApp%20Image%202022-07-01%20at%208.27.31%20AM.jpeg)

# %% [markdown]
# # WeRateDogs Twitter Archive - Act Report
#
# ### Oladipo Olawale
#
# - **DAND Project**
# - **June 2022**
#
# ## WeRateDogs Data
#
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage. The page has been active since November 2015, and with over 9.2 million followers by July 2022. I retrieved data from over 2,000 WeRateDogstweets, including its favorite and retweet count. After some data  cleaning we could see that the puppos (or the equivalent of “Teenager” dogs) are the most retweeted and  liked, also terrier are the most popular dog breeds from all.
#
# ## Wrangling Data
#
# This is where i wrangled the data by cleaning and unifying the datsates. I assessed the data both visually and programmatically for quality and tidiness; the quality of data is determined mainly by looking at several aspects or dimensions to ensure that it is complete, valid, accurate and consistent.
#
# After cleaning many of the issues found during the assessment, there were over 2000 tweets with good quality and tidy data.
#
# ## Insights
#
# **Retweets and likes are strongly correlated.**
#
# There is a strong relationship between a tweet’s retweet counts and favourite counts; in other words if a tweet
# has a high favourite count it will also have a high retweet count. Plotting these two values against each other
# produced the plot below, and clearly shows a high correlation.
#
# **Favourite Counts Are Higher Than Retweet Counts**
#
# The favorite counts being higher than the retweet counts, personally, I get to retweet a tweet rather than like it but this is not surprising to me.
#
# ![Retweet%20and%20fav.png](attachment:Retweet%20and%20fav.png)

# %% [markdown]
# **These are the most popular names you want to name your dogs**
#
# Oliver, Cooper and Charlie are the most popular names after been tweeted 10 times each according to the chart below.

# %% [markdown]
# ![Popular%20names.png](attachment:Popular%20names.png)

# %% [markdown]
# **What is this love with puppos?**
#
# The puppos clearly run away as the most retweeted and liked dog stage.

# %% [markdown]
# ![Fav%20stage.png](attachment:Fav%20stage.png)

# %% [markdown]
# ![Retweet%20stage.png](attachment:Retweet%20stage.png)

# %% [markdown]
# The puppos also come on top as the most rated dog stage along with doggos. Wow!!

# %% [markdown]
# ![Rated%20stage.png](attachment:Rated%20stage.png)

# %% [markdown]
# ![WhatsApp%20Image%202022-07-01%20at%208.27.36%20AM.jpeg](attachment:WhatsApp%20Image%202022-07-01%20at%208.27.36%20AM.jpeg)

# %% [markdown]
# **Labrador retriever is the most loved dog breed**
#
# Grouping all the tweets by the dog breed shows that Labrador_retreiver is the most liked and favorited. Chihuahua and Lakeland_terrier makes us the top 5 breeds of dogs on both groups (see the plots below). There are 8 breeds in common: Labrador_retriever, Eskimo_dog, Chihuahua, Lakeland_terrier, English_springer, Standard_poodle, French_bulldog and Bedlington_terrier.

# %% [markdown]
# ![retweet%20breed.png](attachment:retweet%20breed.png)

# %% [markdown]
# ![loved%20breed.png](attachment:loved%20breed.png)

# %% [markdown]
# When i checked the distibution of dog breeds ratings based on highest favourite counts, I found out the labrador retriver is second while the Golden_retriver tops this charts.

# %% [markdown]
# ![Rate%20breed.png](attachment:Rate%20breed.png)

# %% [markdown]
# **So Many High Ratings with twitter from iphone been the highest source of tweets**
#
# It can also be noted that the tweet from iphone has 98% of the tweet source. This most likely because the tweets are from WeRateDogs themselves.

# %% [markdown]
# ![source.png](attachment:source.png)

# %% [markdown]
# These are the good dogs. haha!!
